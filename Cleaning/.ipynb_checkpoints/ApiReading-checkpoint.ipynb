# %%
import pandas as pd
import cleaning
import numpy as np

# %%
csv = pd.read_csv('Book1.csv')
key = csv['keys'].iloc[0]
key = key.replace('"', '')
cities = ['Los Angeles', 'San Diego', 'San Jose', 'San Francisco', 'Fresno', 'Sacremento', 'Long Beach', 'Oakland', 'Bakersfield', 'Anaheim']
url = "https://us-real-estate.p.rapidapi.com/sold-homes"

# %%
df = cleaning.api_read(cities,200,key,url)

# %%
columns = df.columns.values.tolist()
columns.remove('city')
columns
# Out:
# ['baths',
#  'baths_1qtr',
#  'baths_3qtr',
#  'baths_full',
#  'baths_half',
#  'beds',
#  'garage',
#  'list_price',
#  'lot_sqft',
#  'name',
#  'sold_date',
#  'sold_price',
#  'sqft',
#  'stories',
#  'sub_type',
#  'type',
#  'year_built']

# %%
cleaning.recode_empty_cells(df, columns)

# %%
baths = df['baths'].unique()
baths_1qtr = df['baths_1qtr'].unique()
baths_3qtr = df['baths_3qtr'].unique()
beds = df['beds'].unique()
list = df['list_price'].unique()
print(f"baths: {baths}")
print(f"baths_1qtr: {baths_1qtr}")
print(f"baths_3qtr: {baths_3qtr}")
print(f'beds: {beds}')
print(f"list: {list}")
df.dtypes
# Out:
# baths: [ 1.  2.  3.  5.  4.  0.  7.  6.  8. 16. 36.]
# baths_1qtr: [0]
# baths_3qtr: [0. 2. 1. 4. 3.]
# beds: [ 3.  2.  5.  1.  4.  0.  7. 12.  6.  8.  9. 13. 11. 31. 30.]
# list: [ 745000.  699000. 1200000.  675000.  795000.  259000. 1550000.  799999.
#   775000. 3250000. 1795000.  849000. 1124999.  650000.  850000.  459000.
#  2195000.  599000.  595000.  798000.  995000.  895000.  749500.  579000.
#  1825000. 1290000. 1099000. 1599000.  688800. 1250000. 1100000.  899000.
#   799995. 1399000. 2895000.  575000.  429900.  620000. 1275000.  555000.
#   999000.  449999. 4450000.  949900.  379500. 3295000. 1995000.  499999.
#   695000. 4550000.  499000. 1350000.  465000. 2495000. 4595000.  820000.
#  1600000. 1670000.  845000. 1785000. 1174777. 1249000.  789000.  399000.
#   787900.  765000.  399900.   22900.  450000.  439000.  649000.  370000.
#   519950.  799900. 1325000.  819990.  478900. 1149900. 1875000.  879000.
#  1575000.  525000.  639888.  539000. 2250000. 1149000. 2175000. 3995000.
#  1699000. 1295000. 2711000.  599850. 1615000.  405000.  849900. 1199000.
#  1579000. 4699000.  688000.  949990.  369000. 1425000. 1849000. 1396000.
#   600000.  399999.  500000.  950000. 2349000. 1749000.  889000. 2475000.
#   689000.  189950.  549000. 1349000.  725000. 1075000. 2499000.  630900.
#   925000.  729000.  599900. 6980000.  419000. 1749999.  379750.  674900.
#   487000.  749950.  750000.  519000. 1260000.  114995. 1049000.  548600.
#   489000.  120000.  755000.  599999.  580000.  949000. 2385000. 3500000.
#  1999000. 1499000.  874999.  150000.  569900. 2849000.  780000.  749990.
#   359000.  510000.  482900.  440000.  490000.  194500.  819000.  424950.
#   239000.  710000.  159000.  438000.  123000.  629900.  422000.  402580.
#   479900.  435000.  399500.  329900.  325000.  285000.  255000.  357900.
#   149900.  390000.  920000.  389900.  270000.  509000.  624999.  480000.
#   259900.  494990.  126000.  455000.  530000.  280000.  219500.  468800.
#   539900.  239900.  699900.  473888.  325900.  340000.  330000.  382000.
#   649888.  269900. 1359867.  349000.  829000.  289000.   99500.  197000.
#   275000.  430000.  619000.  359950.  542000.  739950.  534500.  489900.
#   369900.  380000.  374950.  342000.  205000.  610000.  365000.   92000.
#   268000.  167000.  635900.  221000.  475000.  649990.  605000.  249000.
#   915000. 1510000. 1030000.  640000.  364000.  520000. 1035000. 2999000.
#   409000. 3300000.  424900.  779980.  690000.  469999.  708000.  579900.
#   320000.  215000.  769900.  997000.  969000.  879999.  615990.  414500.
#  1239000. 3095000. 1999999. 4200000.  988300.  639000.  365500.  870000.
#   217588.  839000.  559999. 2990000.  665000.  389000. 3175000.  399888.
#   659999.  639900.  849999.  689999.  529500.  312000. 1048900.  128000.
#   809900.  390888.  559900.  519900. 1150000. 1349999. 1285000.  358300.
#   419900.  200000.  940000. 2425000.  715000.  398000. 1089000.  145000.
#  1048000. 1188888.  479000.  945000.  599800.  698000.  766888.  639999.
#   628000.  769000. 1245000.  548000.  502000.  996000.  470000. 1389600.
#   698950.  488000. 1025000.  759000.  568000.  230000.  760800.  708090.
#   599950. 1215000.  658000. 7650000.  598000.  235000.  649995.  678500.
#   949800.   75000.  329000.  299990.  225000. 3400000.  487500.   30000.
#    76900.  445000.  768900.  159900.  314000.  249900.  189000.  355000.
#   294880.  249999.  416000.  417000.  115000.  412000.  224900.  350900.
#   104900.  310500.  269000.   23000.  199000.  324900.  462000.  192500.
#   135000.  379999. 1184000.  387900.   69900.  664900.  214900.  345000.
#   469900.  421900.   70000.  182000.  155000.  279000.  260000.  129950.
#   210000.  309500.  149999.  420000.  262000.  229999.  559000.  280900.
#   165000.  674950.  213000.  240000.  190000.   69999.  154950.  284500.
#   404000.  259500.  325500.  314900.  185000.  279950.  149000.  659900.
#   288800.  443000. 3498888.  728800.  734999.   93000.  719000.  740000.
#   824900.  683000.  779900.  499900.  730000.  809000.  769999.  999999.
#   592999.   49900.  898900.  721000.  589900.  859800.  747000.  770000.
#   588990.  889900.  693000.  799990.  939999.  100000.  720000.  728900.
#  1468000.  505000.  133000.  734900.  725800.  948888.  689900.  649999.
#   448999.  628700. 1358888.   49000.  489500. 2649000.  739900.  590000.]
# baths         float64
# baths_1qtr      int64
# baths_3qtr    float64
# baths_full    float64
# baths_half    float64
# beds          float64
# city           object
# garage        float64
# list_price    float64
# lot_sqft      float64
# name            int64
# sold_date      object
# sold_price    float64
# sqft          float64
# stories       float64
# sub_type       object
# type           object
# year_built    float64
# dtype: object

# %%
df.to_csv('RealEstateData.csv')
