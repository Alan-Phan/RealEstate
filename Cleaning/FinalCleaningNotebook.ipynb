# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('RealEstateData.csv')
columns = list(df)
df.drop(columns[0],axis = 1, inplace=True)
df
# Out:
#       baths  baths_1qtr  baths_3qtr  baths_full  baths_half  beds     city  \
# 0       3.0           0         1.0         1.0         1.0   4.0        0
# 1       3.0           0         0.0         3.0         0.0   3.0        0
# 2       3.0           0         0.0         3.0         0.0   3.0        0
# 3       2.0           0         0.0         2.0         0.0   2.0        0
# 4       2.0           0         0.0         1.0         1.0   2.0        0
# ...     ...         ...         ...         ...         ...   ...      ...
# 1995    3.0           0         0.0         2.0         1.0   3.0  Anaheim
# 1996    2.0           0         0.0         2.0         0.0   2.0  Anaheim
# 1997    2.0           0         0.0         2.0         0.0   3.0  Anaheim
# 1998    3.0           0         0.0         2.0         1.0   4.0  Anaheim
# 1999    2.0           0         0.0         2.0         0.0   4.0  Anaheim
#
#       garage  list_price  lot_sqft  name   sold_date  sold_price    sqft  \
# 0        2.0    889000.0    9347.0     0  2021-08-23    940553.0  2018.0
# 1        2.0   1299000.0   34412.0     0  2021-08-23   1299000.0  3390.0
# 2        2.0   1325000.0   10568.0     0  2021-08-23   1275500.0  3502.0
# 3        3.0    749000.0       0.0     0  2021-08-21    750000.0     0.0
# 4        2.0    399000.0   63423.0     0  2021-08-21    400000.0   937.0
# ...      ...         ...       ...   ...         ...         ...     ...
# 1995     2.0    750000.0    3036.0     0  2021-07-27    820000.0  2023.0
# 1996     2.0    625900.0       0.0     0  2021-07-27    675000.0  1530.0
# 1997     2.0    758000.0    6461.0     0  2021-07-27    758000.0  1228.0
# 1998     3.0    899000.0    7200.0     0  2021-07-26    905500.0  2089.0
# 1999     0.0         0.0    6060.0     0  2021-07-26    700000.0  1240.0
#
#       stories sub_type           type  year_built
# 0         1.0        0  single_family      1960.0
# 1         1.0        0  single_family      1954.0
# 2         2.0        0  single_family      1978.0
# 3         1.0        0  single_family      1925.0
# 4         2.0    condo         condos      1963.0
# ...       ...      ...            ...         ...
# 1995      2.0        0  single_family      1981.0
# 1996      1.0    condo         condos      1980.0
# 1997      1.0        0  single_family      1955.0
# 1998      1.0        0  single_family      1968.0
# 1999      1.0        0  single_family      1957.0
#
# [2000 rows x 18 columns]

# %%
df1 = pd.DataFrame(np.random.rand(100, 5), columns=["a", "b", "c", "d", "e"])

# %%
profile = ProfileReport(df1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-2d5be9a6e8ba> in <module>
# ----> 1 profile = ProfileReport(df1)
#
# ~\anaconda3\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# ~\anaconda3\lib\site-packages\pandas_profiling\describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     390             if name not in names:
#     391                 names.append(name)
# --> 392     variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
#     393     variable_stats.columns.names = df.columns.names
#     394
#
# TypeError: concat() got an unexpected keyword argument 'join_axes'
